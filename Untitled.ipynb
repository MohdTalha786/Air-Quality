# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.express as px
import pandas as pd
from plotly.subplots import make_subplots

# %%
tf=pd.read_csv("Dataset/Complete May data residential 15min.csv")

# %%
tf.columns
# Out:
# Index(['CreatedDate', 'pm25_Surender: Living room',
#        'pm10_Surender: Living room', 'aqi_Surender: Living room',
#        'co2_Surender: Living room', 'voc_Surender: Living room',
#        'temperature_Surender: Living room', 'humidity_Surender: Living room',
#        'pm25_Lakshmi K: Living room', 'pm10_Lakshmi K: Living room',
#        'aqi_Lakshmi K: Living room', 'co2_Lakshmi K: Living room',
#        'voc_Lakshmi K: Living room', 'temperature_Lakshmi K: Living room',
#        'humidity_Lakshmi K: Living room', 'pm25_Abhishek Jain: Living room ',
#        'pm10_Abhishek Jain: Living room ', 'aqi_Abhishek Jain: Living room ',
#        'co2_Abhishek Jain: Living room ', 'voc_Abhishek Jain: Living room ',
#        'temperature_Abhishek Jain: Living room ',
#        'humidity_Abhishek Jain: Living room ', 'pm25_Piyush: Living room ',
#        'pm10_Piyush: Living room ', 'aqi_Piyush: Living room ',
#        'co2_Piyush: Living room ', 'voc_Piyush: Living room ',
# ...

# %%
tf['CreatedDate'] = pd.to_datetime(tf['CreatedDate'], format="%d-%m-%Y %H:%M")
tf['Date'] = tf['CreatedDate'].dt.date

# Group by "date" and calculate the "mean" for each PM source
new_dataframe = pd.concat([
    tf.groupby('Date')[col].mean().reset_index() for col in [
        'co2_Robin: Living room',
        'co2_Mariyam_LR1',
        'co2_Piyush: Living room ',
        'co2_Abhishek Jain: Living room ',
        'co2_Lakshmi K: Living room'
    ]
], axis=1)

# Remove duplicate columns
new_dataframe = new_dataframe.loc[:, ~new_dataframe.columns.duplicated()]

# Plot the line chart
fig = go.Figure()

for col in new_dataframe.columns[1:]:
    fig.add_trace(go.Scatter(
        x=new_dataframe['Date'],
        y=new_dataframe[col],
        name=col.replace('co2_', '').replace(': Living room', ''),
        mode='lines'
    ))

# Update layout
fig.update_layout(
    xaxis_tickangle=-45,
    width=1100,
    height=500,
    title='Line chart for comparison between Mean Co2 for all 6 residential',
    xaxis_title='Date',
    yaxis_title='Avg_Value'
)

fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=tf['CreatedDate'],
    y=tf['co2_Robin: Living room'],
    name='Robin_Co2',
   marker_color='indianred',
))
#fig.add_trace(go.Line(
 #   x=tf['CreatedDate'],
  #  y=tf['pm25_Mariyam_LR1'],
   # name='Mariyam_PM25',
   # marker_color='lightsalmon'
#))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45,width=1100,  # Adjust the width as needed
    height=1000, title='Line chart showing Pm2.5 15 min data for 1 month', xaxis_title='Date',  # Add x-axis label
    yaxis_title='Co2_Value')
fig.show()

# %%
yf=pd.read_csv("Dataset/Complete Residential May Data BR 15min.csv")

# %%
yf.columns
# Out:
# Index(['CreatedDate', 'pm25_Surender: Bedroom', 'pm10_Surender: Bedroom',
#        'aqi_Surender: Bedroom', 'co2_Surender: Bedroom',
#        'voc_Surender: Bedroom', 'temperature_Surender: Bedroom',
#        'humidity_Surender: Bedroom', 'pm25_Piyush: Bedroom ',
#        'pm10_Piyush: Bedroom ', 'aqi_Piyush: Bedroom ', 'co2_Piyush: Bedroom ',
#        'voc_Piyush: Bedroom ', 'temperature_Piyush: Bedroom ',
#        'humidity_Piyush: Bedroom ', 'pm25_Robin: Bedroom',
#        'pm10_Robin: Bedroom', 'aqi_Robin: Bedroom', 'co2_Robin: Bedroom',
#        'voc_Robin: Bedroom', 'temperature_Robin: Bedroom',
#        'humidity_Robin: Bedroom', 'pm25_Mariyam BR1', 'pm10_Mariyam BR1',
#        'aqi_Mariyam BR1', 'co2_Mariyam BR1', 'voc_Mariyam BR1',
#        'temperature_Mariyam BR1', 'humidity_Mariyam BR1',
#        'pm25_Hisham: Bedroom', 'pm10_Hisham: Bedroom', 'aqi_Hisham: Bedroom',
#        'co2_Hisham: Bedroom', 'voc_Hisham: Bedroom',
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=yf['CreatedDate'],
    y=yf['co2_Surender: Bedroom'],
    name='Robin_Co2',
   marker_color='indianred',
))
#fig.add_trace(go.Line(
 #   x=tf['CreatedDate'],
  #  y=tf['pm25_Mariyam_LR1'],
   # name='Mariyam_PM25',
   # marker_color='lightsalmon'
#))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45,width=1100,  # Adjust the width as needed
    height=1000, title='Line chart showing Pm2.5 15 min data for 1 month', xaxis_title='Date',  # Add x-axis label
    yaxis_title='Co2_Value')
fig.show()
